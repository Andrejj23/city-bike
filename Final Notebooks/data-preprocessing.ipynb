# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
DATA_DIR = Path('data/')
PRIOR_DATA_DIR = Path('data/Trips_2018/')
data_path = PRIOR_DATA_DIR / 'Trips_2018.csv'

# %%
data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#    Unnamed: 0  tripduration                 starttime  \
# 0           0           970  2018-01-01 13:50:57.4340
# 1           1           723  2018-01-01 15:33:30.1820
# 2           2           496  2018-01-01 15:39:18.3370
# 3           3           306  2018-01-01 15:40:13.3720
# 4           4           306  2018-01-01 18:14:51.5680
#
#                    stoptime  start_station_id  start_station_latitude  \
# 0  2018-01-01 14:07:08.1860              72.0               40.767272
# 1  2018-01-01 15:45:33.3410              72.0               40.767272
# 2  2018-01-01 15:47:35.1720              72.0               40.767272
# 3  2018-01-01 15:45:20.1910              72.0               40.767272
# 4  2018-01-01 18:19:57.6420              72.0               40.767272
#
#    start_station_longitude  end_station_id  end_station_latitude  \
# 0               -73.993929           505.0             40.749013
# 1               -73.993929          3255.0             40.750585
# 2               -73.993929           525.0             40.755942
# 3               -73.993929           447.0             40.763707
# 4               -73.993929          3356.0             40.774667
#
#    end_station_longitude  bikeid    usertype  birth_year  gender
# 0             -73.988484   31956  Subscriber        1992       1
# 1             -73.994685   32536  Subscriber        1969       1
# 2             -74.002116   16069  Subscriber        1956       1
# 3             -73.985162   31781  Subscriber        1974       1
# 4             -73.984706   30319  Subscriber        1992       1

# %%
data.shape
# Out:
# (17548339, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17548339 entries, 0 to 17548338
# Data columns (total 14 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Unnamed: 0               int64
#  1   tripduration             int64
#  2   starttime                object
#  3   stoptime                 object
#  4   start_station_id         float64
#  5   start_station_latitude   float64
#  6   start_station_longitude  float64
#  7   end_station_id           float64
#  8   end_station_latitude     float64
#  9   end_station_longitude    float64
#  10  bikeid                   int64
#  11  usertype                 object
#  12  birth_year               int64
#  13  gender                   int64
# dtypes: float64(6), int64(5), object(3)
# memory usage: 1.8+ GB

# %%
data.isna().sum()
# Out:
# Unnamed: 0                    0
# tripduration                  0
# starttime                     0
# stoptime                      0
# start_station_id           2497
# start_station_latitude        0
# start_station_longitude       0
# end_station_id             2497
# end_station_latitude          0
# end_station_longitude         0
# bikeid                        0
# usertype                      0
# birth_year                    0
# gender                        0
# dtype: int64

# %% [markdown]
# Drop Unnamed (id Collumn)

# %%
data = data.drop('Unnamed: 0',axis=1)

# %% [markdown]
# Configure datetime to our date data

# %%
data['start_time'] = pd.to_datetime(data['starttime'], format="%Y-%m-%d %H:%M:%S.%f")
data['stop_time'] = pd.to_datetime(data['stoptime'], format="%Y-%m-%d %H:%M:%S.%f")

# %% [markdown]
# Drop old date collumns

# %%
data = data.drop('starttime',axis=1)
data = data.drop('stoptime',axis=1)

# %% [markdown]
# Remove Tuples that have Missing Values

# %%
before = len(data)
data = data.dropna()
after = len(data)

print(f"Before: {before}\nAfter: {after}\nRemoved: {before - after}")
# Out:
# Before: 17548339
# After: 17545842
# Removed: 2497

# %% [markdown]
# Ensure latitude/longitude values fall within New York City bounds.

# %%
before = len(data)

lat_min, lat_max = 40.45, 40.92
lon_min, lon_max = -74.30, -73.65

data = data[
    data["start_station_latitude"].between(lat_min, lat_max)
    & data["start_station_longitude"].between(lon_min, lon_max)
    & data["end_station_latitude"].between(lat_min, lat_max)
    & data["end_station_longitude"].between(lon_min, lon_max)
]

after = len(data)

print("Rows before filtering:", before)
print("Rows after filtering:", after)
print("Rows removed:", before - after)
# Out:
# Rows before filtering: 17548339
# Rows after filtering: 17548257
# Rows removed: 82

# %%
data["usertype"].unique()
# Out:
# array(['Subscriber', 'Customer'], dtype=object)

# %%
data["usertype"] = data["usertype"].map({
    "Subscriber": 1,
    "Customer": 0
})

# %%
before = len(data)
data = data.drop_duplicates()
after = len(data)

print(f"Duplicates removed: {before - after}")
# Out:
# Duplicates removed: 0

# %% [markdown]
# Check if start time is after end time

# %%
mask = data["stop_time"] < data["start_time"]

print("Number of rows with stop_time < start_time:", mask.sum())
# Out:
# Number of rows with stop_time < start_time: 0

# %%
data['tripduration_min'] = (data['tripduration'] / 60).round(2)

# %%
data["duration_min_from_time"] = ((data["stop_time"] - data["start_time"]).dt.total_seconds()/60).round(2)

# %%
diff = (data["tripduration_min"] - data["duration_min_from_time"]).abs()

# %%
n_over_5 = (diff > 5).sum()
print("Rows with difference > 5 minutes:", n_over_5)
# Out:
# Rows with difference > 5 minutes: 151

# %%
mask = diff > 5
rows_over_5 = data[mask]

print("Number of rows with diff > 5:", len(rows_over_5))
rows_over_5
# Out:
# Number of rows with diff > 5: 151
#           tripduration  start_station_id  start_station_latitude  \
# 369257        11138807             501.0               40.744219
# 476336        19510049            3082.0               40.711674
# 656565         8121483            3440.0               40.692418
# 687964        11699746            3537.0               40.680974
# 735287         3615030             151.0               40.722104
# ...                ...               ...                     ...
# 15455425         47057             405.0               40.739323
# 15455874         10197             347.0               40.728846
# 15456532          5978             482.0               40.739355
# 15456671          5299             312.0               40.722055
# 15456712          5091             312.0               40.722055
#
#           start_station_longitude  end_station_id  end_station_latitude  \
# 369257                 -73.971212          3245.0             40.716444
# 476336                 -73.951413           144.0             40.698399
# 656565                 -73.989495          3432.0             40.669060
# 687964                 -73.971010          3245.0             40.716444
# 735287                 -73.997249          3071.0             40.705381
# ...                           ...             ...                   ...
# 15455425               -74.008119          3660.0             40.741022
# 15455874               -74.008591           347.0             40.728846
# 15456532               -73.999318           526.0             40.747659
# 15456671               -73.989111           312.0             40.722055
# 15456712               -73.989111           312.0             40.722055
#
#           end_station_longitude  bikeid    usertype  birth_year  gender  \
# 369257               -73.982331   15336    Customer        1969       0
# 476336               -73.980689   30503    Customer        1953       1
# 656565               -73.994637   25788  Subscriber        1962       1
# 687964               -73.982331   19957    Customer        1969       0
# 735287               -73.949765   32337    Customer        1969       0
# ...                         ...     ...         ...         ...     ...
# 15455425             -74.001385   19606    Customer        1969       0
# 15455874             -74.008591   21335    Customer        1969       0
# 15456532             -73.984907   29173    Customer        1993       1
# 15456671             -73.989111   33268  Subscriber        1999       1
# 15456712             -73.989111   27973    Customer        2000       1
#
#                       start_time               stop_time  tripduration_min  \
# 369257   2018-01-27 15:37:18.019 2018-06-05 14:44:05.591         185646.78
# 476336   2018-01-22 18:20:27.512 2018-09-05 14:47:56.868         325167.48
# 656565   2018-01-14 11:53:04.469 2018-04-18 12:51:08.162         135358.05
# 687964   2018-01-28 03:51:28.614 2018-06-12 14:47:15.583         194995.77
# 735287   2018-02-18 16:12:16.708 2018-04-01 13:22:46.816          60250.50
# ...                          ...                     ...               ...
# 15455425 2018-11-03 23:09:19.401 2018-11-04 11:13:36.983            784.28
# 15455874 2018-11-03 23:36:47.226 2018-11-04 01:26:44.537            169.95
# 15456532 2018-11-04 00:24:57.096 2018-11-04 01:04:35.574             99.63
# 15456671 2018-11-04 00:38:33.031 2018-11-04 01:06:52.148             88.32
# 15456712 2018-11-04 00:41:58.932 2018-11-04 01:06:50.443             84.85
#
#           duration_min_from_time
# 369257                 185706.79
# 476336                 325227.49
# 656565                 135418.06
# 687964                 195055.78
# 735287                  60310.50
# ...                          ...
# 15455425                  724.29
# 15455874                  109.96
# 15456532                   39.64
# 15456671                   28.32
# 15456712                   24.86
#
# [151 rows x 15 columns]

# %%
before = len(data)
data = data[diff<=5]
after = len(data)
print(f"Rows removed due to bad durations: {before - after}")
# Out:
# Rows removed due to bad durations: 151

# %%
data = data.drop(columns=["duration_min_from_time", "tripduration"])

# %%
current_year = data["start_time"].dt.year

data["age"] = current_year - data["birth_year"]

before = len(data)
data = data[(data["age"] >= 10) & (data["age"] <= 90)]
after = len(data)

print(f"Rows removed due to unrealistic age: {before - after}")
# Out:
# Rows removed due to unrealistic age: 13452

# %%
plt.figure(figsize=(6, 4))

plt.hist(data["age"].dropna(), bins=50, edgecolor="black", alpha=0.7)

plt.xlabel("Rider age [years]")
plt.ylabel("Number of trips")
#plt.title("Age distribution of riders")

plt.grid(axis="y", linestyle="--", linewidth=0.5, alpha=0.7)

plt.tight_layout()
plt.show()

# %%
n = (data['age'] > 90).sum()
print("Number of rows with age > 90:", n)
# Out:
# Number of rows with age > 90: 0

# %%
data = data.drop(columns=["birth_year"])

# %%
data.head()
# Out:
#    start_station_id  start_station_latitude  start_station_longitude  \
# 0              72.0               40.767272               -73.993929
# 1              72.0               40.767272               -73.993929
# 2              72.0               40.767272               -73.993929
# 3              72.0               40.767272               -73.993929
# 4              72.0               40.767272               -73.993929
#
#    end_station_id  end_station_latitude  end_station_longitude  bikeid  \
# 0           505.0             40.749013             -73.988484   31956
# 1          3255.0             40.750585             -73.994685   32536
# 2           525.0             40.755942             -74.002116   16069
# 3           447.0             40.763707             -73.985162   31781
# 4          3356.0             40.774667             -73.984706   30319
#
#      usertype  gender              start_time               stop_time  \
# 0  Subscriber       1 2018-01-01 13:50:57.434 2018-01-01 14:07:08.186
# 1  Subscriber       1 2018-01-01 15:33:30.182 2018-01-01 15:45:33.341
# 2  Subscriber       1 2018-01-01 15:39:18.337 2018-01-01 15:47:35.172
# 3  Subscriber       1 2018-01-01 15:40:13.372 2018-01-01 15:45:20.191
# 4  Subscriber       1 2018-01-01 18:14:51.568 2018-01-01 18:19:57.642
#
#    tripduration_min  age
# 0             16.17   26
# 1             12.05   49
# 2              8.27   62
# 3              5.10   44
# 4              5.10   26

# %%
mask = (data['tripduration_min'] >= 1) & (data['tripduration_min'] <= 180)
print("Rows before:", len(data))
print("Rows kept:", mask.sum())
print("Rows removed:", len(data) - mask.sum())
#data[~mask]

data = data[mask]
# Out:
# Rows before: 17534654
# Rows kept: 17505039
# Rows removed: 29615

# %%
durations = data["tripduration_min"].dropna()

plt.figure(figsize=(6, 4))

plt.hist(durations, bins=50, edgecolor="black", alpha=0.7)

plt.xlabel("Trip duration [min]")
plt.ylabel("Number of trips")
#plt.title("Trip duration distribution")

plt.grid(axis="y", linestyle="--", linewidth=0.5, alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.scatter(data["start_station_longitude"], data["start_station_latitude"], s=1)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Start station locations")
plt.show()

# %%
data["gender"].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %% [markdown]
# Gender column is problematic, three types and don't know which column is male/female

# %%
counts = data["usertype"].value_counts()
percent = round(counts / counts.sum() * 100,2)


plt.figure(figsize=(6, 4))

ax = percent.plot(kind="bar", edgecolor="black")

plt.xlabel("User type")
plt.ylabel("Number of trips")
#plt.title("Trips by user type")
plt.xticks(rotation=0)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f"{height:,}",
                (p.get_x() + p.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha="center", va="bottom", fontsize=8)

plt.grid(axis="y", linestyle="--", linewidth=0.5, alpha=0.7)
plt.tight_layout()
plt.show()

# %%
counts = data["usertype"].value_counts()

plt.figure(figsize=(5, 5))

plt.pie(
    counts,
    labels=counts.index,
    autopct="%1.1f%%",
    startangle=90
)


plt.axis("equal")
plt.tight_layout()
plt.show()

# %%
counts = data["gender"].value_counts()

plt.figure(figsize=(5, 5))

plt.pie(
    counts,
    labels=counts.index,
    autopct="%1.1f%%",
    startangle=90
)

#plt.title("Trips by gender")
plt.axis("equal")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns  

daily_counts = (
    data
    .groupby(data["start_time"].dt.date)
    .size()
    .rename("trip_count")
    .to_frame()
)


daily_counts["month"] = pd.to_datetime(daily_counts.index).month


plt.figure(figsize=(10, 6))
sns.boxplot(data=daily_counts, x="month", y="trip_count", order=range(1, 13))

plt.xticks(ticks=range(0, 12), labels=["Jan","Feb","Mar","Apr","May","Jun",
                                       "Jul","Aug","Sep","Oct","Nov","Dec"])

plt.xlabel("Month")
plt.ylabel("Number of trips per day")
#plt.title("Distribution of daily trip counts by month")
plt.show()

# %%
daily_counts = (
    data
    .groupby(data["start_time"].dt.normalize()) 
    .size()
    .rename("trip_count")
    .to_frame()
)


daily_counts["weekday"] = daily_counts.index.day_name()


order = ["Monday", "Tuesday", "Wednesday", "Thursday",
         "Friday", "Saturday", "Sunday"]

plt.figure(figsize=(10, 6))
sns.boxplot(data=daily_counts, x="weekday", y="trip_count", order=order)

plt.xlabel("Day of week")
plt.ylabel("Number of trips per day")
plt.title("Distribution of daily trip counts by weekday")
plt.show()

# %%
mask_not_2018 = (data["start_time"].dt.year != 2018) | \
                (data["stop_time"].dt.year  != 2018)

n_trips_not_2018 = mask_not_2018.sum()
print(n_trips_not_2018)
# Out:
# 8

# %%
data.to_csv(DATA_DIR/ 'Trips_2018_clean.csv', index=False)
